# %%
import os
import sys
sys.path.append(os.path.abspath('..'))
from src.common_lib import DataReader, NBARawData

# %%
data_reader = DataReader()
# Get already split Raw Data
X_train, X_val, y_train, y_val = data_reader.read_data(NBARawData.TRAIN, split = True)

# Load Test Raw Data
test_df = data_reader.read_data(NBARawData.TEST)

# %%
# Out:
#       id_old    id  gp   min   pts  fgm   fga   fg%  3p made  3pa  ...  ftm  \
# 3617   10906  7416  64  13.9   4.3  1.5   3.6  43.0     -0.2 -0.1  ...  1.4
# 1120    7626  4919  81  20.8   7.6  2.7   6.2  44.8      0.4  1.1  ...  1.8
# 3873   11541  7672  50   5.6   1.4  0.5   1.5  36.4      0.0  0.5  ...  0.2
# 153     5697  3952  72  19.3   5.0  2.0   5.0  40.4      0.1  0.5  ...  0.9
# 2960    3428  6759  45  19.7   6.1  2.5   5.9  42.1      0.1  0.4  ...  1.1
# ...      ...   ...  ..   ...   ...  ...   ...   ...      ...  ...  ...  ...
# 2181    6309  5980  74  46.4  18.7  7.4  16.3  45.3      0.8  2.3  ...  3.1
# 2409    8141  6208  59  14.8   3.4  1.0   3.2  33.7      0.5  1.7  ...  1.3
# 2033    3596  5832  55  15.6   3.3  1.1   2.4  44.4      0.6  1.8  ...  0.7
# 1364    4927  5163  91  47.9  12.1  4.2   9.6  46.0      0.4  1.3  ...  3.2
# 4547    3345  8346  67  26.4  12.5  5.6  11.3  49.7     -0.3 -0.7  ...  2.0
#
#       fta   ft%  oreb  dreb  reb  ast  stl  blk  tov
# 3617  1.9  69.2   0.6   1.7  2.2  0.6  0.4  0.1  0.7
# 1120  2.1  79.0   1.7   4.0  5.6  0.7  0.6  0.1  1.3
# 3873  0.2  68.6   0.1   0.2  0.4  1.5  0.4 -0.3  0.3
# 153   1.6  48.4   0.7   2.0  2.9  1.1  0.5  0.2  0.9
# 2960  1.7  62.0   1.0   1.5  2.6  1.5  0.4  0.3  1.8
# ...   ...   ...   ...   ...  ...  ...  ...  ...  ...
# 2181  4.5  68.0   1.9   6.2  8.4  3.4  1.4  0.3  3.0
# 2409  2.0  56.3   0.7   1.2  2.1  1.5  0.9  0.1  0.7
# 2033  1.0  72.7   1.1   2.3  3.3  1.0  0.5  0.3  0.8
# 1364  4.6  66.4   3.0   6.5  9.8  4.2  0.9  0.6  1.6
# 4547  3.0  75.8   2.9   4.9  8.0  0.3  0.6  2.4  1.0
#
# [6400 rows x 21 columns]
