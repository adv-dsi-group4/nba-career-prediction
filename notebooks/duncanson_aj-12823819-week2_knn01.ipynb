# %% [markdown]
# ## NBA Career Prediction Experiment

# %%
experiment_label = 'knn01'

# %% [markdown]
# ### Aim:
# * Test KNN against other alorithms.
#
# * To improve on gb02b, which scored 0.71073 on Kaggle.

# %% [markdown]
# ### Findings:
#
# * Kaggle score =

# %% [markdown]
# ## Set up

# %%
import pandas as pd
import numpy as np
from joblib import dump, load  # simpler than pickle!
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data

# %%
#load data

data_path = '../data/raw/uts-advdsi-nba-career-prediction'

train_raw = pd.read_csv(data_path + '/train.csv')
test_raw = pd.read_csv(data_path + '/test.csv')

# %%
#shapes & head

print(train_raw.shape)
print(test_raw.shape)

train_raw.head()
# Out:
# (8000, 22)
# (3799, 21)
#    Id_old    Id  GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA  ...  FTA   FT%  \
# 0   10556  3799  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  ...  2.9  72.1
# 1    5342  3800  75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  ...  3.6  67.8
# 2    5716  3801  85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  ...  0.6  75.7
# 3   13790  3802  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  ...  1.5  66.9
# 4    5470  3803  63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  ...  0.5  54.0
#
#    OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0   2.2   2.0  3.8  3.2  1.1  0.2  1.6            1
# 1   3.6   3.7  6.6  0.7  0.5  0.6  1.4            1
# 2   0.6   1.8  2.4  0.8  0.4  0.2  0.6            1
# 3   0.8   2.0  3.0  1.8  0.4  0.1  1.9            1
# 4   2.4   2.7  4.9  0.4  0.4  0.6  0.7            1
#
# [5 rows x 22 columns]

# %%
test_raw.head()
# Out:
#    Id_old  Id  GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA  ...  FTM  FTA  \
# 0       1   0  56   9.1   4.0  1.6   3.7  43.7      0.1  0.3  ...  0.7  1.2
# 1    8194   1  43  19.3  10.1  3.7   8.1  46.0      0.6  1.7  ...  1.8  2.5
# 2       3   2  82  33.9  11.3  4.9  10.6  45.6      0.5  1.9  ...  1.8  2.7
# 3    8196   3  86  44.7  18.8  6.8  15.9  42.9      0.5  1.8  ...  4.5  6.3
# 4    8197   4  58  12.3   4.7  1.6   4.0  40.0      0.5  1.7  ...  1.1  1.3
#
#     FT%  OREB  DREB  REB  AST  STL  BLK  TOV
# 0  63.4   1.2   0.8  1.7  0.4  0.2  0.3  0.8
# 1  75.3   0.5   0.9  1.5  3.5  0.6  0.0  1.8
# 2  71.2   1.3   3.3  4.5  2.5  1.3  0.3  2.0
# 3  70.9   1.5   3.2  5.0  4.1  0.9  0.1  3.6
# 4  76.9   0.2   0.6  0.9  1.5  0.5 -0.4  0.9
#
# [5 rows x 21 columns]

# %%
# info
train_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_old       8000 non-null   int64
#  1   Id           8000 non-null   int64
#  2   GP           8000 non-null   int64
#  3   MIN          8000 non-null   float64
#  4   PTS          8000 non-null   float64
#  5   FGM          8000 non-null   float64
#  6   FGA          8000 non-null   float64
#  7   FG%          8000 non-null   float64
#  8   3P Made      8000 non-null   float64
#  9   3PA          8000 non-null   float64
#  10  3P%          8000 non-null   float64
#  11  FTM          8000 non-null   float64
#  12  FTA          8000 non-null   float64
#  13  FT%          8000 non-null   float64
#  14  OREB         8000 non-null   float64
#  15  DREB         8000 non-null   float64
#  16  REB          8000 non-null   float64
#  17  AST          8000 non-null   float64
#  18  STL          8000 non-null   float64
#  19  BLK          8000 non-null   float64
#  20  TOV          8000 non-null   float64
#  21  TARGET_5Yrs  8000 non-null   int64
# dtypes: float64(18), int64(4)
# memory usage: 1.3 MB

# %%
#variable descriptions
train_raw.describe()
# Out:
#              Id_old           Id           GP          MIN          PTS  \
# count   8000.000000   8000.00000  8000.000000  8000.000000  8000.000000
# mean    6856.971000   7798.50000    62.777875    18.576663     7.267087
# std     3977.447579   2309.54541    17.118774     8.935263     4.318732
# min        4.000000   3799.00000    -8.000000     2.900000     0.800000
# 25%     3413.750000   5798.75000    51.000000    12.000000     4.100000
# 50%     6787.500000   7798.50000    63.000000    16.800000     6.300000
# 75%    10299.250000   9798.25000    74.000000    23.500000     9.500000
# max    13798.000000  11798.00000   123.000000    73.800000    34.200000
#
#                FGM          FGA          FG%      3P Made          3PA  ...  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000  ...
# mean      2.807037     6.231213    44.608900     0.264525     0.816563  ...
# std       1.693373     3.584559     6.155453     0.384093     1.060964  ...
# min       0.300000     0.800000    21.300000    -1.100000    -3.100000  ...
# 25%       1.600000     3.600000    40.400000     0.000000     0.100000  ...
# 50%       2.400000     5.400000    44.400000     0.300000     0.800000  ...
# 75%       3.700000     8.100000    48.700000     0.500000     1.500000  ...
# max      13.100000    28.900000    67.200000     1.700000     4.700000  ...
#
#                FTA          FT%         OREB         DREB          REB  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean      1.947787    71.365825     1.077838     2.168500     3.245300
# std       1.252352    10.430447     0.785670     1.392224     2.085154
# min       0.000000   -13.300000     0.000000     0.200000     0.300000
# 25%       1.000000    65.000000     0.500000     1.100000     1.700000
# 50%       1.700000    71.400000     0.900000     1.900000     2.800000
# 75%       2.600000    77.500000     1.500000     2.900000     4.300000
# max      11.100000   168.900000     5.500000    11.000000    15.900000
#
#                AST          STL          BLK          TOV  TARGET_5Yrs
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean      1.624513     0.648688     0.245212     1.257762     0.833625
# std       1.355986     0.407626     0.821037     0.723270     0.372440
# min       0.000000     0.000000   -17.900000     0.100000     0.000000
# 25%       0.700000     0.300000     0.100000     0.700000     1.000000
# 50%       1.300000     0.600000     0.200000     1.100000     1.000000
# 75%       2.200000     0.900000     0.400000     1.600000     1.000000
# max      12.800000     3.600000    18.900000     5.300000     1.000000
#
# [8 rows x 22 columns]

# %%
test_raw.describe()
# Out:
#              Id_old           Id           GP          MIN          PTS  \
# count   3799.000000  3799.000000  3799.000000  3799.000000  3799.000000
# mean    7010.614109  1899.000000    62.853909    18.650224     7.328034
# std     3954.173641  1096.821164    17.151740     8.727259     4.294724
# min        1.000000     0.000000     6.000000     3.700000     0.700000
# 25%     3644.000000   949.500000    51.000000    12.200000     4.200000
# 50%     7062.000000  1899.000000    63.000000    17.000000     6.400000
# 75%    10402.500000  2848.500000    74.000000    23.300000     9.400000
# max    13792.000000  3798.000000   126.000000    68.000000    33.000000
#
#                FGM          FGA          FG%      3P Made          3PA  ...  \
# count  3799.000000  3799.000000  3799.000000  3799.000000  3799.000000  ...
# mean      2.835404     6.302580    44.599079     0.255962     0.796920  ...
# std       1.688427     3.579221     6.040168     0.380987     1.052862  ...
# min       0.300000     0.800000    25.100000    -1.000000    -2.700000  ...
# 25%       1.600000     3.700000    40.500000     0.000000     0.100000  ...
# 50%       2.500000     5.500000    44.600000     0.300000     0.800000  ...
# 75%       3.700000     8.100000    48.500000     0.500000     1.500000  ...
# max      13.400000    26.200000    74.600000     1.600000     4.300000  ...
#
#                FTM          FTA          FT%         OREB         DREB  \
# count  3799.000000  3799.000000  3799.000000  3799.000000  3799.000000
# mean      1.399842     1.953567    71.612924     1.096025     2.179495
# std       0.926140     1.250376    10.457336     0.785678     1.371935
# min       0.000000     0.000000    23.700000     0.000000     0.200000
# 25%       0.700000     1.000000    65.000000     0.500000     1.200000
# 50%       1.200000     1.700000    71.500000     0.900000     1.900000
# 75%       1.900000     2.600000    78.000000     1.500000     2.900000
# max       7.800000     9.800000   127.100000     6.900000    12.000000
#
#                REB          AST          STL          BLK          TOV
# count  3799.000000  3799.000000  3799.000000  3799.000000  3799.000000
# mean      3.275783     1.636483     0.653593     0.257726     1.257910
# std       2.070646     1.335496     0.410573     0.639660     0.712449
# min       0.300000     0.000000     0.000000    -7.100000     0.100000
# 25%       1.800000     0.600000     0.400000     0.100000     0.700000
# 50%       2.800000     1.300000     0.600000     0.200000     1.100000
# 75%       4.300000     2.300000     0.900000     0.400000     1.600000
# max      18.500000     9.000000     2.700000    14.800000     5.200000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## Decisions
#
# For XGBoost we will retain all potential features.
#
# and TARGET_5Yrs is our target.

# %% [markdown]
# ## Cleaning

# %%
train = train_raw.copy()
test = test_raw.copy()

# %%
cols_drop = ['Id_old', 'Id'] #, 'MIN', 'FGM', 'FGA', 'TOV', '3PA', 'FTM', 'FTA', 'REB']
train.drop(cols_drop, axis=1, inplace=True)
test.drop(cols_drop, axis=1, inplace=True)

# %%
train.head()
# Out:
#    GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA   3P%  FTM  FTA   FT%  OREB  \
# 0  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  22.6  2.0  2.9  72.1   2.2
# 1  75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  34.9  2.4  3.6  67.8   3.6
# 2  85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  34.3  0.4  0.6  75.7   0.6
# 3  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  23.7  0.9  1.5  66.9   0.8
# 4  63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  13.7  0.2  0.5  54.0   2.4
#
#    DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0   2.0  3.8  3.2  1.1  0.2  1.6            1
# 1   3.7  6.6  0.7  0.5  0.6  1.4            1
# 2   1.8  2.4  0.8  0.4  0.2  0.6            1
# 3   2.0  3.0  1.8  0.4  0.1  1.9            1
# 4   2.7  4.9  0.4  0.4  0.6  0.7            1

# %%
test.head()
# Out:
#    GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA   3P%  FTM  FTA   FT%  OREB  \
# 0  56   9.1   4.0  1.6   3.7  43.7      0.1  0.3   7.3  0.7  1.2  63.4   1.2
# 1  43  19.3  10.1  3.7   8.1  46.0      0.6  1.7  35.1  1.8  2.5  75.3   0.5
# 2  82  33.9  11.3  4.9  10.6  45.6      0.5  1.9  44.8  1.8  2.7  71.2   1.3
# 3  86  44.7  18.8  6.8  15.9  42.9      0.5  1.8  13.5  4.5  6.3  70.9   1.5
# 4  58  12.3   4.7  1.6   4.0  40.0      0.5  1.7  38.7  1.1  1.3  76.9   0.2
#
#    DREB  REB  AST  STL  BLK  TOV
# 0   0.8  1.7  0.4  0.2  0.3  0.8
# 1   0.9  1.5  3.5  0.6  0.0  1.8
# 2   3.3  4.5  2.5  1.3  0.3  2.0
# 3   3.2  5.0  4.1  0.9  0.1  3.6
# 4   0.6  0.9  1.5  0.5 -0.4  0.9

# %%
train_target = train.pop('TARGET_5Yrs')

# %%
#examine shapes

print('train:' + str(train.shape))
print('test:' + str(test.shape))
# Out:
# train:(8000, 19)
# test:(3799, 19)

# %%
# target class balance check
from collections import Counter

counter = Counter(train_target)
print(counter)
# Out:
# Counter({1: 6669, 0: 1331})

# %% [markdown]
# # Modelling

# %%
#transformations

# scaling - not for tree-based model

# %%
# class imbalance pipeline

# !pip install imblearn

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

from imblearn.pipeline import Pipeline
# Out:
# Requirement already satisfied: imblearn in /opt/conda/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /opt/conda/lib/python3.8/site-packages (from imblearn) (0.7.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.6.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.0.0)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.20.0)
# Requirement already satisfied: scikit-learn>=0.23 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn>=0.23->imbalanced-learn->imblearn) (2.1.0)

# %%
# split training into train & validation

validation = False

if validation:
    from sklearn.model_selection import train_test_split
    X_train, X_val, y_train, y_val = train_test_split(train, train_target, test_size=0.2, random_state=8)
else:
    #in this case we will use CV
    X_train, y_train = train, train_target

# %%
#import models

#from sklearn.ensemble import GradientBoostingClassifier 
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

#from sklearn.model_selection import cross_val_score

# %%
# Define model
classifier = KNeighborsClassifier()

# Define parameters
param_grid = {
    'model__n_neighbors': [150, 160, 170, 180, 190, 200],
    'over__sampling_strategy': [0.25, 0.35],
    'under__sampling_strategy': [0.75, 0.85]
}

# Define cv
cv = RepeatedStratifiedKFold(
    n_splits=10, n_repeats=3, random_state=8
)

# Define model pipeline
model = Pipeline([
        ('over', SMOTE()),    
        #('over', RandomOverSampler(sampling_strategy=0.25)),
        ('under', RandomUnderSampler()),
        ('model', classifier)
    ])

# Define grid search
grid = GridSearchCV(estimator=model,
                           param_grid=param_grid, 
                           scoring='roc_auc', 
                           cv=cv)

# %%
# Fit model

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=8),
#              estimator=Pipeline(steps=[('over', SMOTE()),
#                                        ('under', RandomUnderSampler()),
#                                        ('model', KNeighborsClassifier())]),
#              param_grid={'model__n_neighbors': [150, 160, 170, 180, 190, 200],
#                          'over__sampling_strategy': [0.25, 0.35],
#                          'under__sampling_strategy': [0.75, 0.85]},
#              scoring='roc_auc')

# %%
# can use this to get best result but doesn't actually do the fitting??

#scores = cross_val_score(pipeline, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
#from numpy import mean
#print('Mean ROC AUC: %.3f' % mean(scores))

# %%
# Score of best model

mean_score = grid.cv_results_["mean_test_score"][grid.best_index_]
std_score = grid.cv_results_["std_test_score"][grid.best_index_]

grid.best_params_, mean_score, std_score

print(f"Best parameters: {grid.best_params_}")
print(f"Mean CV score: {mean_score: .6f}")
print(f"Standard deviation of CV score: {std_score: .6f}")
# Out:
# Best parameters: {'model__n_neighbors': 150, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}
# Mean CV score:  0.693636
# Standard deviation of CV score:  0.023903

# %%
print(grid.cv_results_)
# Out:
# {'mean_fit_time': array([0.04282577, 0.04127366, 0.04715885, 0.04643235, 0.04405453,
#        0.04587273, 0.04992457, 0.04649053, 0.04604427, 0.04626133,
#        0.04929298, 0.04842804, 0.04777214, 0.04825945, 0.06832228,
#        0.05764267, 0.05437899, 0.0663586 , 0.06719324, 0.06058122,
#        0.07317496, 0.06483967, 0.0628695 , 0.05796146]), 'std_fit_time': array([0.01363441, 0.00303447, 0.00264235, 0.00393058, 0.00265923,
#        0.00240142, 0.00529021, 0.00248619, 0.00331854, 0.00247299,
#        0.00182571, 0.0030303 , 0.00380062, 0.0026773 , 0.01783877,
#        0.00598389, 0.00255069, 0.00954839, 0.00702384, 0.00545614,
#        0.01031567, 0.00788876, 0.00360193, 0.00329899]), 'mean_score_time': array([0.06060531, 0.05665077, 0.09701101, 0.08215496, 0.06663657,
#        0.06690305, 0.10064611, 0.08520777, 0.06918193, 0.06622691,
#        0.10007416, 0.08778615, 0.07294842, 0.06915874, 0.13070762,
#        0.10359464, 0.08335453, 0.09399676, 0.1326412 , 0.11066726,
#        0.11035635, 0.09527514, 0.12813915, 0.10707348]), 'std_score_time': array([0.00925772, 0.00724644, 0.00594946, 0.00470479, 0.0039939 ,
#        0.00387724, 0.00973755, 0.00356063, 0.00410165, 0.00605946,
#        0.00326706, 0.00354473, 0.00456523, 0.00348976, 0.02601696,
#        0.01137587, 0.00519746, 0.01095085, 0.00927345, 0.00845957,
#        0.01066078, 0.00874933, 0.01001191, 0.00631135]), 'param_model__n_neighbors': masked_array(data=[150, 150, 150, 150, 160, 160, 160, 160, 170, 170, 170,
#                    170, 180, 180, 180, 180, 190, 190, 190, 190, 200, 200,
#                    200, 200],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_over__sampling_strategy': masked_array(data=[0.25, 0.25, 0.35, 0.35, 0.25, 0.25, 0.35, 0.35, 0.25,
#                    0.25, 0.35, 0.35, 0.25, 0.25, 0.35, 0.35, 0.25, 0.25,
#                    0.35, 0.35, 0.25, 0.25, 0.35, 0.35],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_under__sampling_strategy': masked_array(data=[0.75, 0.85, 0.75, 0.85, 0.75, 0.85, 0.75, 0.85, 0.75,
#                    0.85, 0.75, 0.85, 0.75, 0.85, 0.75, 0.85, 0.75, 0.85,
#                    0.75, 0.85, 0.75, 0.85, 0.75, 0.85],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'model__n_neighbors': 150, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 150, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 150, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 150, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 160, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 160, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 160, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 160, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 170, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 170, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 170, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 170, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 180, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 180, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 180, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 180, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 190, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 190, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 190, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 190, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 200, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 200, 'over__sampling_strategy': 0.25, 'under__sampling_strategy': 0.85}, {'model__n_neighbors': 200, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.75}, {'model__n_neighbors': 200, 'over__sampling_strategy': 0.35, 'under__sampling_strategy': 0.85}], 'split0_test_score': array([0.68953117, 0.69217459, 0.67966205, 0.68578305, 0.69354421,
#        0.68626213, 0.68603668, 0.68653831, 0.69156587, 0.69610871,
#        0.6865834 , 0.68737248, 0.69397256, 0.69602417, 0.68765429,
#        0.68499397, 0.69424874, 0.68972281, 0.68876464, 0.68462761,
#        0.69338639, 0.68998208, 0.68920427, 0.68461634]), 'split1_test_score': array([0.69278894, 0.68696103, 0.68826301, 0.68480234, 0.68373144,
#        0.68547305, 0.68964954, 0.69286222, 0.68917045, 0.68745702,
#        0.69144187, 0.68562523, 0.68905773, 0.69247331, 0.68772193,
#        0.69702743, 0.68621704, 0.69004971, 0.6986394 , 0.68956499,
#        0.68860119, 0.6856816 , 0.69539854, 0.68923809]), 'split2_test_score': array([0.70105737, 0.70306388, 0.68710194, 0.68015804, 0.69733179,
#        0.68417107, 0.67985932, 0.69242822, 0.69789541, 0.69621017,
#        0.68929445, 0.69106424, 0.69171241, 0.69026953, 0.68523069,
#        0.69515055, 0.69409092, 0.69756287, 0.68469525, 0.68477415,
#        0.6956409 , 0.69981175, 0.68689903, 0.69397256]), 'split3_test_score': array([0.70099537, 0.70672746, 0.69834632, 0.68994826, 0.69853231,
#        0.69017371, 0.69094588, 0.6985154 , 0.69580999, 0.69874086,
#        0.69853231, 0.70566784, 0.70041483, 0.69921994, 0.69677943,
#        0.70133354, 0.69739378, 0.70081501, 0.69911285, 0.70128282,
#        0.70275952, 0.70159281, 0.69672307, 0.70051628]), 'split4_test_score': array([0.70016683, 0.70034156, 0.68934518, 0.69604108, 0.69845904,
#        0.69529145, 0.6907937 , 0.69788978, 0.69698234, 0.70272007,
#        0.69064716, 0.68924936, 0.69973848, 0.69478982, 0.69305385,
#        0.70125464, 0.69519   , 0.69644689, 0.70460259, 0.69123333,
#        0.69953557, 0.69710633, 0.69489691, 0.70251716]), 'split5_test_score': array([0.73240635, 0.72529337, 0.73149328, 0.71943164, 0.74111441,
#        0.72777897, 0.72236814, 0.73385488, 0.72887241, 0.72683771,
#        0.73048438, 0.7247861 , 0.72281341, 0.72997712, 0.71864256,
#        0.73808772, 0.7348525 , 0.7311551 , 0.72498337, 0.72308395,
#        0.72506228, 0.73947988, 0.72031653, 0.72274577]), 'split6_test_score': array([0.68443598, 0.68579432, 0.68291982, 0.6722447 , 0.68582814,
#        0.68570414, 0.68117821, 0.68485306, 0.68639177, 0.68827428,
#        0.67003528, 0.67882224, 0.68646504, 0.6822491 , 0.68765429,
#        0.68404707, 0.68347781, 0.68521378, 0.68462197, 0.6868314 ,
#        0.68538851, 0.69074297, 0.6846107 , 0.68231674]), 'split7_test_score': array([0.68150511, 0.67057637, 0.67253215, 0.66665915, 0.66677188,
#        0.67285906, 0.67388486, 0.67597592, 0.6726167 , 0.6631083 ,
#        0.66571789, 0.66542481, 0.67795426, 0.66838949, 0.67890679,
#        0.67718209, 0.66972529, 0.67341141, 0.66964638, 0.67069473,
#        0.66208813, 0.66969711, 0.67583501, 0.66519936]), 'split8_test_score': array([0.65161592, 0.64997013, 0.64714072, 0.64214134, 0.64610928,
#        0.64600219, 0.64773252, 0.65149192, 0.6485216 , 0.65116502,
#        0.64905141, 0.64324605, 0.65157647, 0.65317717, 0.65462006,
#        0.65282209, 0.65294045, 0.65167228, 0.6518301 , 0.65442279,
#        0.65361116, 0.65130593, 0.65365062, 0.64372513]), 'split9_test_score': array([0.71427211, 0.6969096 , 0.70051208, 0.70525189, 0.70742571,
#        0.70213124, 0.70288199, 0.70480929, 0.70438909, 0.70299404,
#        0.70104433, 0.70372798, 0.70636121, 0.70457398, 0.70281476,
#        0.71236162, 0.70252342, 0.69959885, 0.70601385, 0.70707835,
#        0.70711757, 0.70370557, 0.71252409, 0.71368383]), 'split10_test_score': array([0.67170362, 0.66663661, 0.65812582, 0.66578553, 0.67474158,
#        0.67513048, 0.66557135, 0.67156271, 0.6668226 , 0.67081873,
#        0.6638861 , 0.67338887, 0.67580683, 0.68022004, 0.67362559,
#        0.66508099, 0.6804624 , 0.68276764, 0.67073418, 0.66658588,
#        0.67759353, 0.67995514, 0.67138235, 0.67036782]), 'split11_test_score': array([0.68856737, 0.67946478, 0.67765553, 0.67719336, 0.68847155,
#        0.68939027, 0.6811613 , 0.67904769, 0.68965517, 0.67963387,
#        0.67886733, 0.68171929, 0.68303254, 0.67657337, 0.6807724 ,
#        0.68558578, 0.68935081, 0.67665228, 0.6820631 , 0.67960569,
#        0.68363563, 0.68054694, 0.68102603, 0.67558138]), 'split12_test_score': array([0.67923933, 0.6742174 , 0.67705245, 0.66420737, 0.67186144,
#        0.67511357, 0.67137672, 0.66817531, 0.67489939, 0.67597029,
#        0.66786532, 0.68189965, 0.6787377 , 0.6782248 , 0.67160781,
#        0.67533339, 0.676703  , 0.6789406 , 0.6723067 , 0.68089639,
#        0.67948169, 0.68625086, 0.67081309, 0.67559829]), 'split13_test_score': array([0.71350791, 0.71849602, 0.70861562, 0.70686837, 0.70856489,
#        0.72622899, 0.71039105, 0.7077589 , 0.71575115, 0.7212747 ,
#        0.70442222, 0.70508731, 0.71315282, 0.72297686, 0.71079686,
#        0.71499589, 0.71668113, 0.72119016, 0.70748836, 0.70950051,
#        0.71504661, 0.71349664, 0.71719967, 0.71136049]), 'split14_test_score': array([0.72881604, 0.72881041, 0.73002221, 0.72113943, 0.7252201 ,
#        0.73273326, 0.72804387, 0.72862441, 0.73744519, 0.7304562 ,
#        0.72181015, 0.73636302, 0.72544555, 0.73393378, 0.72398012,
#        0.7272097 , 0.72558645, 0.72454374, 0.72229487, 0.72748024,
#        0.73151018, 0.73100856, 0.73262617, 0.73058583]), 'split15_test_score': array([0.6918815 , 0.68470652, 0.69462637, 0.68219274, 0.68103166,
#        0.68399071, 0.69311585, 0.68561396, 0.68101476, 0.6842218 ,
#        0.68872519, 0.68715266, 0.68744575, 0.69112061, 0.68701739,
#        0.68471216, 0.68786847, 0.67788662, 0.68952554, 0.69182514,
#        0.68813338, 0.67729481, 0.6879812 , 0.68992571]), 'split16_test_score': array([0.70399387, 0.70238753, 0.70493513, 0.69986247, 0.70562839,
#        0.70186899, 0.7050084 , 0.69471655, 0.70101228, 0.7062202 ,
#        0.71331627, 0.70727982, 0.70626529, 0.70595529, 0.70292861,
#        0.70496331, 0.70141245, 0.69848159, 0.70553257, 0.70534094,
#        0.6964638 , 0.69265931, 0.69682452, 0.69138551]), 'split17_test_score': array([0.69570854, 0.69552818, 0.69680761, 0.67895751, 0.70065155,
#        0.70374024, 0.68661158, 0.6866454 , 0.70363878, 0.69591144,
#        0.68787411, 0.6913686 , 0.70156463, 0.70161536, 0.69035407,
#        0.69125024, 0.70402205, 0.70525076, 0.69567472, 0.68898446,
#        0.69457564, 0.69552818, 0.69469401, 0.68914227]), 'split18_test_score': array([0.67887861, 0.68223783, 0.67763299, 0.67429631, 0.68165166,
#        0.67669737, 0.67556447, 0.68008477, 0.67830371, 0.67423995,
#        0.6814262 , 0.6737665 , 0.6799495 , 0.67036219, 0.67845588,
#        0.68229419, 0.68026513, 0.67996641, 0.67755408, 0.68200674,
#        0.67880533, 0.67708627, 0.67614501, 0.67644937]), 'split19_test_score': array([0.67973757, 0.68090852, 0.65917036, 0.67377639, 0.68564833,
#        0.68965421, 0.67199476, 0.68149119, 0.68262852, 0.6787347 ,
#        0.67386043, 0.67471763, 0.68368742, 0.66687957, 0.67708754,
#        0.67438147, 0.68167048, 0.67854422, 0.67509861, 0.67663372,
#        0.67950787, 0.68040989, 0.67257743, 0.67795034]), 'split20_test_score': array([0.67258852, 0.66714387, 0.65724656, 0.6650979 , 0.66990001,
#        0.66601662, 0.6554035 , 0.66043106, 0.66956184, 0.67182762,
#        0.65672239, 0.67167544, 0.67088636, 0.68265491, 0.66691842,
#        0.66271376, 0.67838825, 0.67708063, 0.66915602, 0.65789474,
#        0.66704805, 0.67183326, 0.66817531, 0.68011859]), 'split21_test_score': array([0.66845149, 0.66407774, 0.66757223, 0.66098905, 0.66174432,
#        0.66053815, 0.66275321, 0.66364374, 0.66539662, 0.66548681,
#        0.66768495, 0.65808073, 0.66112433, 0.67020437, 0.66753841,
#        0.66606734, 0.66903203, 0.66368883, 0.66344647, 0.66250521,
#        0.66823167, 0.66948856, 0.66513172, 0.66537972]), 'split22_test_score': array([0.70077555, 0.70163227, 0.70620893, 0.70127154, 0.69931012,
#        0.71191284, 0.70428695, 0.70047119, 0.70362751, 0.7055213 ,
#        0.70173372, 0.70436023, 0.70756163, 0.707494  , 0.7089087 ,
#        0.70416296, 0.70371769, 0.70224662, 0.70166608, 0.71530588,
#        0.71219465, 0.70731927, 0.70681201, 0.70397132]), 'split23_test_score': array([0.70626529, 0.69703306, 0.69395002, 0.69305385, 0.70516058,
#        0.69644689, 0.69392184, 0.6996483 , 0.70353733, 0.69265367,
#        0.69389929, 0.69756287, 0.70575802, 0.70106864, 0.69896067,
#        0.70395441, 0.70484495, 0.70515494, 0.69559581, 0.69314403,
#        0.70150263, 0.70015556, 0.69569726, 0.69170114]), 'split24_test_score': array([0.6390132 , 0.64264296, 0.63962192, 0.64007846, 0.64526383,
#        0.64791289, 0.64349968, 0.64947414, 0.63835376, 0.64390549,
#        0.65910654, 0.64996449, 0.6367756 , 0.64877524, 0.6458951 ,
#        0.64351095, 0.64003337, 0.64324605, 0.64266551, 0.63599215,
#        0.64193843, 0.6467969 , 0.64954741, 0.6468589 ]), 'split25_test_score': array([0.71077431, 0.7069811 , 0.68922118, 0.70147445, 0.70434332,
#        0.7032217 , 0.70423059, 0.70370642, 0.70081501, 0.70485622,
#        0.70225226, 0.70128845, 0.70974287, 0.70027392, 0.70845216,
#        0.70446168, 0.70542548, 0.7086438 , 0.70199299, 0.70991196,
#        0.70327806, 0.70317661, 0.69704433, 0.70728546]), 'split26_test_score': array([0.7369661 , 0.73538231, 0.72752534, 0.73650956, 0.74343092,
#        0.73903462, 0.73214145, 0.7279706 , 0.74374655, 0.73871899,
#        0.73492577, 0.7337027 , 0.73573739, 0.7353034 , 0.73210763,
#        0.72909222, 0.74051132, 0.74410727, 0.73236126, 0.73253599,
#        0.74214021, 0.73573176, 0.73729301, 0.73430014]), 'split27_test_score': array([0.68558578, 0.69197168, 0.69673434, 0.69147569, 0.68634668,
#        0.68459943, 0.70048247, 0.69333003, 0.68798683, 0.69127278,
#        0.6982505 , 0.69319476, 0.68443034, 0.68889427, 0.68815592,
#        0.69535909, 0.6859465 , 0.688883  , 0.70003156, 0.68744575,
#        0.69107551, 0.68826865, 0.69229295, 0.68587323]), 'split28_test_score': array([0.74547689, 0.73759737, 0.73947425, 0.73402397, 0.73521886,
#        0.73416487, 0.73924316, 0.73972224, 0.7361883 , 0.73995333,
#        0.73835263, 0.73384924, 0.73794682, 0.73193854, 0.73941225,
#        0.72685462, 0.73492577, 0.73294744, 0.72516373, 0.73878662,
#        0.73601357, 0.73125655, 0.74034223, 0.7374621 ]), 'split29_test_score': array([0.66236946, 0.65827395, 0.65403837, 0.65776971, 0.66054861,
#        0.66004437, 0.66278966, 0.6526209 , 0.67022433, 0.65820111,
#        0.65393752, 0.65604971, 0.6616019 , 0.66062704, 0.66014522,
#        0.66038613, 0.66348998, 0.66554054, 0.6532484 , 0.66042535,
#        0.66450406, 0.66597194, 0.6588174 , 0.66614562]), 'mean_test_score': array([0.69363587, 0.69113141, 0.68778513, 0.68561617, 0.69178622,
#        0.69114292, 0.68843076, 0.68979862, 0.69209417, 0.69144985,
#        0.68872505, 0.68958194, 0.69222399, 0.69220799, 0.69020665,
#        0.69155437, 0.69269992, 0.6923804 , 0.6898837 , 0.68988005,
#        0.69219572, 0.69211139, 0.6907494 , 0.69019915]), 'std_test_score': array([0.02390295, 0.02355739, 0.02471924, 0.02357606, 0.0243148 ,
#        0.02394222, 0.023539  , 0.02302127, 0.02423657, 0.02409533,
#        0.0234178 , 0.02346492, 0.02307568, 0.022946  , 0.0216621 ,
#        0.02307584, 0.02284456, 0.02305413, 0.02213661, 0.02383752,
#        0.02335033, 0.02249139, 0.02297381, 0.02299191]), 'rank_test_score': array([ 1, 13, 23, 24,  9, 12, 22, 19,  8, 11, 21, 20,  4,  5, 15, 10,  2,
#         3, 17, 18,  6,  7, 14, 16], dtype=int32)}

# %%
#save model to file

dump(grid,  '../models/aj_' + experiment_label + '.joblib')
# Out:
# ['../models/aj_knn01.joblib']

# %%
#predictions for train set

y_train_preds = grid.predict(X_train)

if validation:
    y_val_preds = grid.predict(X_val)

# %% [markdown]
# ## Evaluation

# %%
from sklearn import metrics

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.models.aj_metrics import confusion_matrix

# %%
# Show TRAINING confusion matrix with labels

print("Training:")
print(confusion_matrix(y_train, y_train_preds))

if validation:
    print("Val:")
    print(confusion_matrix(y_val, y_val_preds))
# Out:
# Training:
#         pred:0  pred:1
# true:0     700     631
# true:1    1657    5012

# %%
print(metrics.classification_report(y_train, y_train_preds))
if validation:
    print(metrics.classification_report(y_val, y_val_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.53      0.38      1331
#            1       0.89      0.75      0.81      6669
#
#     accuracy                           0.71      8000
#    macro avg       0.59      0.64      0.60      8000
# weighted avg       0.79      0.71      0.74      8000

# %%
import matplotlib.pyplot as plt  
from sklearn import metrics
metrics.plot_roc_curve(grid, X_train, y_train)
plt.show() 
if validation:
    metrics.plot_roc_curve(grid, X_val, y_val)
    plt.show()

# %% [markdown]
# # Apply to test data for submission

# %%
y_test_preds = grid.predict(test)

# %%
y_test_preds
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
y_test_probs = grid.predict_proba(test)

# %%
y_test_probs
# Out:
# array([[0.56      , 0.44      ],
#        [0.50666667, 0.49333333],
#        [0.25333333, 0.74666667],
#        ...,
#        [0.50666667, 0.49333333],
#        [0.18666667, 0.81333333],
#        [0.41333333, 0.58666667]])

# %%
len(y_test_probs)
# Out:
# 3799

# %%
test_raw.shape
# Out:
# (3799, 21)

# %%
test_raw['Id'].shape
# Out:
# (3799,)

# %%
submission = pd.DataFrame({'Id': range(0,3799), 'TARGET_5Yrs': [p[1] for p in y_test_probs]})

# %%
submission.head()
# Out:
#    Id  TARGET_5Yrs
# 0   0     0.440000
# 1   1     0.493333
# 2   2     0.746667
# 3   3     0.860000
# 4   4     0.540000

# %%
submission.to_csv('../reports/aj_' + experiment_label + 'submission.csv',
                 index=False,
                 )
